# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["HF_TOKEN"] = os.getenv("HF_TOKEN")

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model= "openai/gpt-oss-20b",
)

# %%
from langchain.chat_models import init_chat_model

models = init_chat_model("llama-3.1-8b-instant", model_provider="groq")
models
# Out:
# ChatGroq(output_version=None, profile={'max_input_tokens': 131072, 'max_output_tokens': 8192, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x000001C8F8A8D090>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001C8F8C0ED10>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
response = models.invoke("Hey!! How are you?")

# %%
response.content
# Out:
# "I'm just a language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to help with any questions or tasks you have. How can I assist you today?"

# %%
model1 = init_chat_model("gemini-3.1-flash-lite", model_provider="google_genai")
model1
# Out:
# ChatGoogleGenerativeAI(output_version=None, profile={'name': 'Gemini 3.1 Flash Lite', 'release_date': '2026-05-07', 'last_updated': '2026-05-07', 'open_weights': False, 'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True}, google_api_key=SecretStr('**********'), location=None, model='gemini-3.1-flash-lite', temperature=1.0, client=<google.genai.client.Client object at 0x000001C8FBB8F550>, default_metadata=(), model_kwargs={})

# %%
response = model1.invoke("Hey!! How are you?")

# %%
response.content
# Out:
# [{'type': 'text',
#   'text': "I'm doing great, thank you for asking! How are things going with you? Anything on your mind today?",
#   'extras': {'signature': 'EjQKMgEMOdbH1ull/+nqOkYBStdYLCu4uQxf0u/KGf5/mngtlUFyCmQTY+n7AmeuDy7mbVBm'}}]

# %%
model2 = init_chat_model("gemini-3.", model_provider="google_genai")
model2
